# %% [markdown]
# # Data Update Notebook
# - Notebook detailing ```update_database.py``` and ```db_functions.py``` in ```db-build``` directory

# %% [markdown]
# ## Add New Data
# - Add new members of the house (monthly)
# - Add new bills voted on (weekly)

# %%
# API Key
import configparser

# Read/Scrape data
import requests
import json
import re
from bs4 import BeautifulSoup

# %%
config = configparser.ConfigParser()
config.read('auth/config.ini')
PROPUBLICA_API_KEY = config.get('propublica', 'PROPUBLICA_API_KEY')
API_ROOT = 'https://api.propublica.org/congress/v1/'
header = {'X-API-Key': f'{PROPUBLICA_API_KEY}'}

# %%
def get_house_ids(congress):
    '''
    Function to get house members' ProPublica ID by congress number
    '''

    call_string = API_ROOT + f'{congress}/house/members.json'
    r = requests.get(call_string, headers=header)
    result = r.json()['results'][0]['members']
    member_ids = [ member['id'] for member in result ]
    
    return member_ids

def get_member_data(member):
    '''
    Function to get house member's data
    '''
    
    call_string = API_ROOT + f'members/{member}.json'
    r = requests.get(call_string, headers=header)
    result = r.json()['results'][0]
    
    return result

# %% [markdown]
# ## Get Initial Congress and Clean Data/Select Features

# %%
# House members of the 116th Congress (2018-2020)
ids_116 = get_house_ids(116)
members_116 = [ get_member_data(member) for member in ids_116 ]

# %%
from pprint import pprint
from datetime import datetime

# %%
def to_date(s):
    date = datetime.strptime(s, '%Y-%m-%d')
    return date

# %%
def member_cleaner(member):
    '''
    Function to keep relevent information on congress member
    '''
    
    roles = member['roles']
    roles.sort(key=lambda x: x['congress'], reverse=True)
    fec_id = roles[0]['fec_candidate_id']
    
    mem_dict = {
        '_id': member['id'],
        'bio': {
            'first_name': member['first_name'],
            'middle_name': member['middle_name'],
            'last_name': member['last_name'],
            'dob': to_date(member['date_of_birth']),
            'gender': member['gender'],
            'current_party': member['current_party'],
        },
        'activity': {
            'last_updated': to_date(member['last_updated'][:10]), # Ignore time
            'in_office': member['in_office'],
        },
        'other_ids': {
            'google_id': member['google_entity_id'],
            'votesmart_id': member['votesmart_id'],
            'govtrack_id': member['govtrack_id'],
            'cspan_id': member['cspan_id'],
            'crp_id': member['crp_id'],
            'fec_id': fec_id,
        },
        'roles': member['roles'],   
    }
    
    return mem_dict

# %% [markdown]
# ## Inserting into Google Firestore

# %%
# Database connection and authentication
import firebase_admin
from firebase_admin import credentials, firestore
from google.cloud.firestore_v1.batch import WriteBatch

# %%
GCP_AUTH_PATH = config.get('firebase', 'GCP_AUTH_PATH')
cred = credentials.Certificate(GCP_AUTH_PATH)
app = firebase_admin.initialize_app(cred)

# %%
# Database
db = firestore.client()

# %%
members_insert = map(member_cleaner, members_116)

# %%
def batch_insert_members(members, db):
    '''
    Function to batch insert house members into database
    '''
    
    batch = db.batch()
    members_len = 0
    for member in members:
        _id = member['_id']
        insert_ref = db.collection("reps").document(f"{_id}")
        batch.set(insert_ref, member)
        members_len += 1
            
    batch.commit()
    
    batch_len = len(batch.write_results)
    f_string = f'Batch Length: {batch_len}, Members Length: {members_len}'
    assert batch_len == members_len, f_string
    
    return f'{batch_len} members inserted'

# %%
batch_insert_members(members_insert, db)
# Out:
# '451 members inserted'

# %% [markdown]
# ## Creating Query Functions
# - Google Firestore requires composite indices to be created when query across multiple fields.

# %%
def where_(ref, field, operator, value):
    ref = ref.where(field, operator, value)
    return ref

# %%
def query_(collection, field, operator, value, order_by=True, limit=10):
    ref = db.collection(collection)
    query = ref.where(field, operator, value)
    if order_by == None:
        pass
    elif order_by == field:
        query = order_by_(query, order_by)
    else:
        response = create_index(collection, field, order_by)
        query = order_by_(query, order_by)
        
    if limit:
        query = limit_(query, limit)
    return query.stream()

# %%
reps_ref = db.collection('reps')
date = datetime(1980, 1, 1)
query = reps_ref.where('bio.dob', '>=', date).order_by('bio.dob').limit(10).stream()

# %%
docs = [ doc.to_dict() for doc in query ]

# %%
docs
# Out:
# [{'bio': {'dob': DatetimeWithNanoseconds(1980, 1, 30, 0, 0, tzinfo=<UTC>),
#    'middle_name': None,
#    'last_name': 'Zeldin',
#    'current_party': 'R',
#    'first_name': 'Lee',
#    'gender': 'M'},
#   'roles': [{'votes_against_party_pct': 0.0,
#     'party': 'R',
#     'bills_sponsored': 2,
#     'fec_candidate_id': 'H8NY01148',
#     'dw_nominate': 0.388,
#     'cook_pvi': None,
#     'phone': '202-225-3826',
#     'state': 'NY',
#     'at_large': False,
#     'committees': [],
#     'office': '2441 Rayburn House Office Building',
#     'leadership_role': None,
#     'lis_id': '',
#     'end_date': '2023-01-03',
#     'votes_with_party_pct': 93.75,
#     'missed_votes_pct': 5.56,
#     'state_rank': '',
#     'ocd_id': 'ocd-division/country:us/state:ny/cd:1',
#     'start_date': '2021-01-03',
#     'total_present': 0,
#     'fax': None,
#     'seniority': '8',
#     'ideal_point': None,
#     'short_title': 'Rep.',
#     'next_election': '2022',
#     'title': 'Representative',
#     'senate_class': '',
#     'total_votes': 18,
#     'bills_cosponsored': 8,
#     'subcommittees': [],
#     'congress': '117',
#     'contact_form': None,
#     'district': '1',
#     'chamber': 'House',
#     'missed_votes': 1},
#    {'committees': [{'api_uri': 'https://api.propublica.org/congress/v1/116/house/committees/HSBA.json',
#       'side': 'minority',
#       'title': 'Member',
#       'name': 'Committee on Financial Services',
#       'rank_in_party': 13,
#       'code': 'HSBA',
#       'end_date': '2021-01-03',
#       'begin_date': '2019-01-23'},
#      {'end_date': '2021-01-03',
#       'code': 'HSFA',
#       'rank_in_party': 8,
#       'name': 'Committee on Foreign Affairs',
#       'begin_date': '2019-01-23',
#       'side': 'minority',
#       'api_uri': 'https://api.propublica.org/congress/v1/116/house/committees/HSFA.json',
#       'title': 'Member'}],
#     'party': 'R',
#     'fax': None,
#     'title': 'Representative',
#     'next_election': '2020',
#     'at_large': False,
#     'total_votes': 954,
#     'missed_votes': 13,
#     'fec_candidate_id': 'H8NY01148',
#     'seniority': '6',
#     'contact_form': None,
#     'dw_nominate': 0.387,
#     'ideal_point': None,
#     'ocd_id': 'ocd-division/country:us/state:ny/cd:1',
#     'votes_against_party_pct': 10.19,
#     'state': 'NY',
#     'congress': '116',
#     'start_date': '2019-01-03',
#     'bills_sponsored': 27,
#     'office': '2441 Rayburn House Office Building',
#     'chamber': 'House',
#     'phone': '202-225-3826',
#     'missed_votes_pct': 1.36,
#     'state_rank': '',
#     'subcommittees': [{'begin_date': '2019-01-29',
#       'api_uri': 'https://api.propublica.org/congress/v1/116/house/committees/HSFA/subcommittees/HSFA17.json',
#       'parent_committee_id': 'HSFA',
#       'side': 'minority',
#       'code': 'HSFA17',
#       'rank_in_party': 1,
#       'name': 'Oversight and Investigations',
#       'title': 'Ranking Member',
#       'end_date': '2021-01-03'},
#      {'parent_committee_id': 'HSFA',
#       'side': 'minority',
#       'rank_in_party': 4,
#       'begin_date': '2019-01-29',
#       'end_date': '2021-01-03',
#       'api_uri': 'https://api.propublica.org/congress/v1/116/house/committees/HSFA/subcommittees/HSFA13.json',
#       'name': 'Middle East, North Africa, and International Terrorism',
#       'title': 'Member',
#       'code': 'HSFA13'},
#      {'end_date': '2021-01-03',
#       'side': 'minority',
#       'code': 'HSBA04',
#       'title': 'Member',
#       'rank_in_party': 5,
#       'name': 'Housing, Community Development, and Insurance',
#       'parent_committee_id': 'HSBA',
#       'api_uri': 'https://api.propublica.org/congress/v1/116/house/committees/HSBA/subcommittees/HSBA04.json',
#       'begin_date': ''},
#      {'api_uri': 'https://api.propublica.org/congress/v1/116/house/committees/HSBA/subcommittees/HSBA09.json',
#       'begin_date': '',
#       'side': 'minority',
#       'code': 'HSBA09',
#       'parent_committee_id': 'HSBA',
#       'title': 'Member',
#       'rank_in_party': 3,
#       'name': 'Oversight and Investigations',
#       'end_date': '2021-01-03'}],
#     'cook_pvi': 'R+5',
#     'leadership_role': None,
#     'senate_class': '',
#     'end_date': '2021-01-03',
#     'short_title': 'Rep.',
#     'district': '1',
#     'total_present': 0,
#     'votes_with_party_pct': 89.7,
#     'lis_id': '',
#     'bills_cosponsored': 289},
#    {'bills_sponsored': 31,
#     'short_title': 'Rep.',
#     'office': '1517 Longworth House Office Building',
#     'leadership_role': None,
#     'title': 'Representative',
#     'total_votes': 1211,
#     'committees': [{'side': 'majority',
#       'title': 'Member',
#       'code': 'HSBA',
#       'api_uri': 'https://api.propublica.org/congress/v1/115/house/committees/HSBA.json',
#       'name': 'Committee on Financial Services',
#       'begin_date': '',
#       'rank_in_party': 25,
#       'end_date': '2019-01-03'},
#      {'name': 'Committee on Foreign Affairs',
#       'title': 'Member',
#       'api_uri': 'https://api.propublica.org/congress/v1/115/house/committees/HSFA.json',
#       'side': 'majority',
#       'rank_in_party': 18,
#       'begin_date': '',
#       'end_date': '2019-01-03',
#       'code': 'HSFA'}],
#     'state_rank': '',
#     'lis_id': '',
#     'cook_pvi': None,
#     'total_present': 0,
#     'bills_cosponsored': 286,
#     'missed_votes_pct': 2.89,
#     'seniority': '4',
#     'next_election': '2018',
#     'contact_form': None,
#     'congress': '115',
#     'phone': '202-225-3826',
#     'votes_against_party_pct': 5.81,
#     'fax': '202-225-3143',
#     'ocd_id': 'ocd-division/country:us/state:ny/cd:1',
#     'party': 'R',
#     'at_large': False,
#     'end_date': '2019-01-03',
#     'dw_nominate': 0.362,
#     'ideal_point': None,
#     'chamber': 'House',
#     'fec_candidate_id': 'H8NY01148',
#     'missed_votes': 35,
#     'district': '1',
#     'start_date': '2017-01-03',
#     'votes_with_party_pct': 94.19,
#     'subcommittees': [{'side': 'majority',
#       'title': 'Member',
#       'parent_committee_id': 'HSBA',
#       'code': 'HSBA01',
#       'end_date': '2019-01-03',
#       'api_uri': 'https://api.propublica.org/congress/v1/115/house/committees/HSBA/subcommittees/HSBA01.json',
#       'name': 'National Security, International Development, and Monetary Policy',
#       'begin_date': '',
#       'rank_in_party': 11},
#      {'side': 'majority',
#       'name': 'Housing, Community Development, and Insurance',
#       'parent_committee_id': 'HSBA',
#       'rank_in_party': 10,
#       'code': 'HSBA04',
#       'begin_date': '',
#       'api_uri': 'https://api.propublica.org/congress/v1/115/house/committees/HSBA/subcommittees/HSBA04.json',
#       'end_date': '2019-01-03',
#       'title': 'Member'},
#      {'side': 'majority',
#       'begin_date': '',
#       'parent_committee_id': 'HSBA',
#       'title': 'Member',
#       'code': 'HSBA09',
#       'end_date': '2019-01-03',
#       'rank_in_party': 7,
#       'api_uri': 'https://api.propublica.org/congress/v1/115/house/committees/HSBA/subcommittees/HSBA09.json',
#       'name': 'Oversight and Investigations'},
#      {'title': 'Member',
#       'begin_date': '',
#       'code': 'HSFA13',
#       'side': 'majority',
#       'parent_committee_id': 'HSFA',
#       'name': 'Middle East, North Africa, and International Terrorism',
#       'end_date': '2019-01-03',
#       'rank_in_party': 7,
#       'api_uri': 'https://api.propublica.org/congress/v1/115/house/committees/HSFA/subcommittees/HSFA13.json'},
#      {'begin_date': '',
#       'name': 'Oversight and Investigations',
#       'rank_in_party': 6,
#       'title': 'Member',
#       'end_date': '2019-01-03',
#       'parent_committee_id': 'HSFA',
#       'api_uri': 'https://api.propublica.org/congress/v1/115/house/committees/HSFA/subcommittees/HSFA18.json',
#       'code': 'HSFA18',
#       'side': 'majority'}],
#     'state': 'NY',
#     'senate_class': ''},
#    {'state_rank': '',
#     'next_election': '2016',
#     'end_date': '2017-01-03',
#     'party': 'R',
#     'missed_votes_pct': 0.38,
#     'chamber': 'House',
#     'ideal_point': None,
#     'committees': [{'api_uri': 'https://api.propublica.org/congress/v1/114/house/committees/HSFA.json',
#       'name': 'Committee on Foreign Affairs',
#       'rank_in_party': 24,
#       'code': 'HSFA',
#       'begin_date': '',
#       'end_date': '2017-01-03'},
#      {'end_date': '2017-01-03',
#       'rank_in_party': 33,
#       'name': 'Committee on Transportation and Infrastructure',
#       'api_uri': 'https://api.propublica.org/congress/v1/114/house/committees/HSPW.json',
#       'code': 'HSPW',
#       'begin_date': ''},
#      {'begin_date': '',
#       'code': 'HSVR',
#       'name': "Committee on Veterans' Affairs",
#       'end_date': '2017-01-03',
#       'api_uri': 'https://api.propublica.org/congress/v1/114/house/committees/HSVR.json',
#       'rank_in_party': 11}],
#     'congress': '114',
#     'missed_votes': 5,
#     'total_votes': 1325,
#     'senate_class': '',
#     'dw_nominate': 0.363,
#     'short_title': 'Rep.',
#     'seniority': '2',
#     'fec_candidate_id': 'H8NY01148',
#     'total_present': 0,
#     'phone': None,
#     'lis_id': '',
#     'district': '1',
#     'at_large': False,
#     'votes_with_party_pct': 92.6,
#     'fax': None,
#     'state': 'NY',
#     'votes_against_party_pct': 7.33,
#     'bills_sponsored': 13,
#     'cook_pvi': None,
#     'bills_cosponsored': 164,
#     'title': 'Representative',
#     'office': None,
#     'leadership_role': None,
#     'contact_form': None,
#     'start_date': '2015-01-06',
#     'ocd_id': 'ocd-division/country:us/state:ny/cd:1',
#     'subcommittees': []}],
#   '_id': 'Z000017',
#   'activity': {'in_office': True,
#    'last_updated': DatetimeWithNanoseconds(2021, 1, 28, 0, 0, tzinfo=<UTC>)},
#   'other_ids': {'govtrack_id': '412646',
#    'crp_id': 'N00029404',
#    'votesmart_id': '110252',
#    'cspan_id': '61616',
#    'google_id': '/m/03h4jcq',
#    'fec_id': 'H8NY01148'}},
#  {'activity': {'last_updated': DatetimeWithNanoseconds(2020, 12, 31, 0, 0, tzinfo=<UTC>),
#    'in_office': False},
#   'roles': [{'phone': None,
#     'chamber': 'House',
#     'state_rank': '',
#     'contact_form': None,
#     'office': None,
#     'bills_sponsored': 22,
#     'subcommittees': [],
#     'cook_pvi': 'R+6',
#     'votes_with_party_pct': 58.49,
#     'dw_nominate': None,
#     'fec_candidate_id': '',
#     'next_election': '2020',
#     'district': '3',
#     'missed_votes_pct': 0.0,
#     'end_date': '2021-01-03',
#     'short_title': 'Rep.',
#     'start_date': '2019-07-08',
#     'votes_against_party_pct': 41.51,
#     'missed_votes': 0,
#     'party': 'I',
#     'lis_id': '',
#     'committees': [],
#     'bills_cosponsored': 0,
#     'at_large': False,
#     'congress': '116',
#     'total_votes': 524,
#     'state': 'MI',
#     'total_present': 10,
#     'fax': None,
#     'seniority': '10',
#     'title': 'Representative',
#     'leadership_role': '',
#     'ocd_id': 'ocd-division/country:us/state:mi/cd:3',
#     'ideal_point': None,
#     'senate_class': ''},
#    {'total_votes': 430,
#     'at_large': False,
#     'votes_against_party_pct': 37.79,
#     'ideal_point': None,
#     'fec_candidate_id': 'H0MI03126',
#     'total_present': 5,
#     'ocd_id': 'ocd-division/country:us/state:mi/cd:3',
#     'end_date': '2019-07-08',
#     'congress': '116',
#     'bills_cosponsored': 23,
#     'leadership_role': '',
#     'state': 'MI',
#     'votes_with_party_pct': 61.97,
#     'chamber': 'House',
#     'cook_pvi': None,
#     'lis_id': '',
#     'missed_votes': 0,
#     'next_election': '2020',
#     'title': 'Representative',
#     'party': 'R',
#     'committees': [{'begin_date': '2019-01-23',
#       'api_uri': 'https://api.propublica.org/congress/v1/116/house/committees/HSGO.json',
#       'title': 'Member',
#       'side': 'minority',
#       'code': 'HSGO',
#       'name': 'Committee on Oversight and Reform',
#       'end_date': '2019-07-08',
#       'rank_in_party': 2}],
#     'office': '106 Cannon House Office Building',
#     'bills_sponsored': 7,
#     'state_rank': '',
#     'senate_class': '',
#     'missed_votes_pct': 0.0,
#     'phone': '202-225-3831',
#     'short_title': 'Rep.',
#     'dw_nominate': 0.654,
#     'subcommittees': [{'api_uri': 'https://api.propublica.org/congress/v1/116/house/committees/HSGO/subcommittees/HSGO06.json',
#       'name': 'National Security',
#       'code': 'HSGO06',
#       'side': 'minority',
#       'rank_in_party': 2,
#       'parent_committee_id': 'HSGO',
#       'title': 'Member',
#       'end_date': '2019-07-08',
#       'begin_date': '2019-01-29'},
#      {'begin_date': '',
#       'parent_committee_id': 'HSGO',
#       'api_uri': 'https://api.propublica.org/congress/v1/116/house/committees/HSGO/subcommittees/HSGO02.json',
#       'end_date': '2019-07-08',
#       'title': 'Member',
#       'code': 'HSGO02',
#       'name': 'Civil Rights and Civil Liberties',
#       'rank_in_party': 2,
#       'side': 'minority'}],
#     'seniority': '10',
#     'contact_form': None,
#     'fax': None,
#     'district': '3',
#     'start_date': '2019-01-03'},
#    {'fax': '202-225-5144',
#     'ocd_id': 'ocd-division/country:us/state:mi/cd:3',
#     'cook_pvi': None,
#     'votes_with_party_pct': 66.2,
#     'chamber': 'House',
#     'congress': '115',
#     'fec_candidate_id': 'H0MI03126',
#     'leadership_role': None,
#     'end_date': '2019-01-03',
#     'total_votes': 1211,
#     'dw_nominate': 0.648,
#     'short_title': 'Rep.',
#     'start_date': '2017-01-03',
#     'votes_against_party_pct': 33.8,
#     'title': 'Representative',
#     'seniority': '8',
#     'contact_form': None,
#     'missed_votes_pct': 0.08,
#     'phone': '202-225-3831',
#     'state': 'MI',
#     'office': '114 Cannon House Office Building',
#     'total_present': 2,
#     'senate_class': '',
#     'at_large': False,
#     'bills_sponsored': 11,
#     'state_rank': '',
#     'bills_cosponsored': 55,
#     'committees': [{'begin_date': '',
#       'title': 'Member',
#       'rank_in_party': 6,
#       'code': 'HSGO',
#       'end_date': '2019-01-03',
#       'name': 'Committee on Oversight and Reform',
#       'api_uri': 'https://api.propublica.org/congress/v1/115/house/committees/HSGO.json',
#       'side': 'majority'}],
#     'ideal_point': None,
#     'missed_votes': 1,
#     'subcommittees': [{'api_uri': 'https://api.propublica.org/congress/v1/115/house/committees/HSGO/subcommittees/HSGO06.json',
#       'side': 'majority',
#       'code': 'HSGO06',
#       'rank_in_party': 4,
#       'begin_date': '',
#       'title': 'Member',
#       'parent_committee_id': 'HSGO',
#       'end_date': '2019-01-03',
#       'name': 'National Security'},
#      {'parent_committee_id': 'HSGO',
#       'begin_date': '',
#       'title': 'Member',
#       'end_date': '2019-01-03',
#       'rank_in_party': 4,
#       'code': 'HSGO25',
#       'side': 'majority',
#       'name': 'Information Technology',
#       'api_uri': 'https://api.propublica.org/congress/v1/115/house/committees/HSGO/subcommittees/HSGO25.json'}],
#     'party': 'R',
#     'next_election': '2018',
#     'lis_id': '',
#     'district': '3'},
#    {'state_rank': '',
#     'votes_against_party_pct': 24.26,
#     'committees': [{'rank_in_party': 2,
#       'end_date': '2017-01-03',
#       'code': 'JSEC',
#       'name': 'Joint Economic Committee',
#       'api_uri': 'https://api.propublica.org/congress/v1/114/house/committees/JSEC.json',
#       'begin_date': ''},
#      {'name': 'Committee on Oversight and Reform',
#       'rank_in_party': 7,
#       'code': 'HSGO',
#       'begin_date': '',
#       'api_uri': 'https://api.propublica.org/congress/v1/114/house/committees/HSGO.json',
#       'end_date': '2017-01-03'}],
#     'congress': '114',
#     'district': '3',
#     'total_present': 3,
#     'next_election': '2016',
#     'bills_sponsored': 9,
#     'short_title': 'Rep.',
#     'senate_class': '',
#     'at_large': False,
#     'title': 'Representative',
#     'cook_pvi': None,
#     'fec_candidate_id': 'H0MI03126',
#     'ideal_point': None,
#     'bills_cosponsored': 44,
#     'total_votes': 1325,
#     'missed_votes_pct': 0.0,
#     'party': 'R',
#     'phone': None,
#     'votes_with_party_pct': 75.67,
#     'office': None,
#     'ocd_id': 'ocd-division/country:us/state:mi/cd:3',
#     'lis_id': '',
#     'seniority': '6',
#     'chamber': 'House',
#     'missed_votes': 0,
#     'state': 'MI',
#     'fax': None,
#     'contact_form': None,
#     'end_date': '2017-01-03',
#     'dw_nominate': 0.649,
#     'subcommittees': [],
#     'start_date': '2015-01-06',
#     'leadership_role': None},
#    {'votes_with_party_pct': 77.31,
#     'short_title': 'Rep.',
#     'cook_pvi': None,
#     'senate_class': '',
#     'congress': '113',
#     'dw_nominate': 0.649,
#     'subcommittees': [],
#     'ideal_point': 0.521346012,
#     'leadership_role': None,
#     'committees': [{'api_uri': 'https://api.propublica.org/congress/v1/113/house/committees/JSEC.json',
#       'name': 'Joint Economic Committee',
#       'end_date': '2015-01-03',
#       'rank_in_party': 4,
#       'code': 'JSEC',
#       'begin_date': '2013-02-14'},
#      {'name': 'Committee on Oversight and Reform',
#       'rank_in_party': 10,
#       'begin_date': '2013-01-04',
#       'code': 'HSGO',
#       'api_uri': 'https://api.propublica.org/congress/v1/113/house/committees/HSGO.json',
#       'end_date': '2015-01-03'}],
#     'total_votes': 1204,
#     'ocd_id': 'ocd-division/country:us/state:mi/cd:3',
#     'phone': None,
#     'contact_form': None,
#     'total_present': 2,
#     'district': '3',
#     'fec_candidate_id': '',
#     'state': 'MI',
#     'fax': None,
#     'party': 'R',
#     'bills_cosponsored': 76,
#     'chamber': 'House',
#     'at_large': False,
#     'start_date': '2013-01-03',
#     'next_election': '',
#     'bills_sponsored': 7,
#     'end_date': '2015-01-03',
#     'lis_id': '',
#     'missed_votes': 0,
#     'office': None,
#     'title': 'Representative',
#     'state_rank': '',
#     'missed_votes_pct': 0.0,
#     'votes_against_party_pct': 22.6,
#     'seniority': '4'},
#    {'seniority': '2',
#     'at_large': False,
#     'end_date': '2013-01-03',
#     'next_election': '',
#     'ocd_id': 'ocd-division/country:us/state:mi/cd:3',
#     'fax': None,
#     'senate_class': '',
#     'state': 'MI',
#     'office': None,
#     'chamber': 'House',
#     'bills_sponsored': 8,
#     'missed_votes': 0,
#     'cook_pvi': None,
#     'phone': None,
#     'votes_against_party_pct': 25.02,
#     'total_present': 41,
#     'total_votes': 1607,
#     'start_date': '2011-01-04',
#     'bills_cosponsored': 65,
#     'lis_id': '',
#     'fec_candidate_id': '',
#     'votes_with_party_pct': 74.92,
#     'district': '3',
#     'short_title': 'Rep.',
#     'subcommittees': [],
#     'missed_votes_pct': 0.0,
#     'congress': '112',
#     'contact_form': None,
#     'state_rank': '',
#     'dw_nominate': 0.649,
#     'title': 'Representative',
#     'leadership_role': None,
#     'committees': [{'name': 'Joint Economic Committee',
#       'code': 'JSEC',
#       'rank_in_party': 5,
#       'begin_date': '2011-01-26',
#       'api_uri': 'https://api.propublica.org/congress/v1/112/house/committees/JSEC.json',
#       'end_date': '2013-01-03'},
#      {'api_uri': 'https://api.propublica.org/congress/v1/112/house/committees/HSGO.json',
#       'code': 'HSGO',
#       'rank_in_party': 12,
#       'end_date': '2013-01-03',
#       'begin_date': '2011-01-18',
#       'name': 'Committee on Oversight and Reform'},
#      {'name': 'Committee on the Budget',
#       'rank_in_party': 20,
#       'code': 'HSBU',
#       'begin_date': '2011-01-18',
#       'api_uri': 'https://api.propublica.org/congress/v1/112/house/committees/HSBU.json',
#       'end_date': '2013-01-03'}],
#     'ideal_point': None,
#     'party': 'R'}],
#   '_id': 'A000367',
#   'bio': {'first_name': 'Justin',
#    'current_party': 'I',
#    'dob': DatetimeWithNanoseconds(1980, 4, 18, 0, 0, tzinfo=<UTC>),
#    'gender': 'M',
#    'middle_name': None,
#    'last_name': 'Amash'},
#   'other_ids': {'google_id': '/m/0c00p_n',
#    'cspan_id': '1033767',
#    'votesmart_id': '105566',
#    'fec_id': '',
#    'crp_id': 'N00031938',
#    'govtrack_id': '412438'}},
#  {'bio': {'gender': 'F',
#    'middle_name': None,
#    'last_name': 'Davids',
#    'dob': DatetimeWithNanoseconds(1980, 5, 22, 0, 0, tzinfo=<UTC>),
#    'first_name': 'Sharice',
#    'current_party': 'D'},
#   '_id': 'D000629',
#   'activity': {'in_office': True,
#    'last_updated': DatetimeWithNanoseconds(2021, 1, 28, 0, 0, tzinfo=<UTC>)},
#   'roles': [{'committees': [],
#     'district': '3',
#     'next_election': '2022',
#     'contact_form': None,
#     'fec_candidate_id': 'H8KS03155',
#     'lis_id': '',
#     'leadership_role': None,
#     'subcommittees': [],
#     'state_rank': '',
#     'ocd_id': 'ocd-division/country:us/state:ks/cd:3',
#     'votes_against_party_pct': 0.0,
#     'end_date': '2023-01-03',
#     'at_large': False,
#     'missed_votes': 0,
#     'chamber': 'House',
#     'ideal_point': None,
#     'total_votes': 18,
#     'fax': None,
#     'total_present': 0,
#     'party': 'D',
#     'bills_sponsored': 1,
#     'senate_class': '',
#     'bills_cosponsored': 5,
#     'office': '1541 Longworth House Office Building',
#     'title': 'Representative',
#     'dw_nominate': None,
#     'congress': '117',
#     'missed_votes_pct': 0.0,
#     'seniority': '4',
#     'start_date': '2021-01-03',
#     'cook_pvi': None,
#     'phone': '202-225-2865',
#     'votes_with_party_pct': 94.12,
#     'state': 'KS',
#     'short_title': 'Rep.'},
#    {'bills_sponsored': 10,
#     'state_rank': '',
#     'phone': '202-225-2865',
#     'congress': '116',
#     'leadership_role': None,
#     'ocd_id': 'ocd-division/country:us/state:ks/cd:3',
#     'dw_nominate': None,
#     'lis_id': '',
#     'missed_votes': 5,
#     'fax': None,
#     'votes_against_party_pct': 2.53,
#     'senate_class': '',
#     'end_date': '2021-01-03',
#     'district': '3',
#     'chamber': 'House',
#     'short_title': 'Rep.',
#     'cook_pvi': 'R+4',
#     'state': 'KS',
#     'seniority': '2',
#     'party': 'D',
#     'title': 'Representative',
#     'votes_with_party_pct': 97.36,
#     'total_votes': 954,
#     'committees': [{'code': 'HSSM',
#       'name': 'Committee on Small Business',
#       'api_uri': 'https://api.propublica.org/congress/v1/116/house/committees/HSSM.json',
#       'begin_date': '2019-01-24',
#       'title': 'Member',
#       'rank_in_party': 6,
#       'side': 'majority',
#       'end_date': '2021-01-03'},
#      {'title': 'Member',
#       'rank_in_party': 31,
#       'api_uri': 'https://api.propublica.org/congress/v1/116/house/committees/HSPW.json',
#       'end_date': '2021-01-03',
#       'begin_date': '2017-01-17',
#       'side': 'majority',
#       'code': 'HSPW',
#       'name': 'Committee on Transportation and Infrastructure'}],
#     'fec_candidate_id': 'H8KS03155',
#     'subcommittees': [{'title': 'Member',
#       'parent_committee_id': 'HSPW',
#       'code': 'HSPW05',
#       'name': 'Aviation',
#       'rank_in_party': 18,
#       'side': 'majority',
#       'end_date': '2021-01-03',
#       'begin_date': '',
#       'api_uri': 'https://api.propublica.org/congress/v1/116/house/committees/HSPW/subcommittees/HSPW05.json'},
#      {'parent_committee_id': 'HSSM',
#       'end_date': '2021-01-03',
#       'title': 'Member',
#       'rank_in_party': 6,
#       'begin_date': '',
#       'code': 'HSSM26',
#       'side': 'majority',
#       'name': 'Innovation and Workforce Development',
#       'api_uri': 'https://api.propublica.org/congress/v1/116/house/committees/HSSM/subcommittees/HSSM26.json'},
#      {'code': 'HSPW12',
#       'api_uri': 'https://api.propublica.org/congress/v1/116/house/committees/HSPW/subcommittees/HSPW12.json',
#       'side': 'majority',
#       'name': 'Highways and Transit',
#       'end_date': '2021-01-03',
#       'title': 'Member',
#       'parent_committee_id': 'HSPW',
#       'rank_in_party': 17,
#       'begin_date': ''},
#      {'code': 'HSPW13',
#       'rank_in_party': 3,
#       'api_uri': 'https://api.propublica.org/congress/v1/116/house/committees/HSPW/subcommittees/HSPW13.json',
#       'name': 'Economic Development, Public Buildings, and Emergency Management',
#       'title': 'Member',
#       'side': 'majority',
#       'parent_committee_id': 'HSPW',
#       'end_date': '2021-01-03',
#       'begin_date': ''},
#      {'title': 'Member',
#       'name': 'Economic Growth, Tax and Capital Access',
#       'begin_date': '',
#       'side': 'majority',
#       'code': 'HSSM27',
#       'end_date': '2021-01-03',
#       'parent_committee_id': 'HSSM',
#       'rank_in_party': 2,
#       'api_uri': 'https://api.propublica.org/congress/v1/116/house/committees/HSSM/subcommittees/HSSM27.json'}],
#     'ideal_point': None,
#     'next_election': '2020',
#     'office': '1541 Longworth House Office Building',
#     'bills_cosponsored': 316,
#     'start_date': '2019-01-03',
#     'contact_form': None,
#     'total_present': 0,
#     'at_large': False,
#     'missed_votes_pct': 0.52}],
#   'other_ids': {'votesmart_id': '181201',
#    'crp_id': 'N00042626',
#    'google_id': '/g/11fgm1fq16',
#    'cspan_id': None,
#    'fec_id': 'H8KS03155',
#    'govtrack_id': '412780'}},
#  {'bio': {'first_name': 'Chris',
#    'gender': 'M',
#    'current_party': 'D',
#    'middle_name': None,
#    'dob': DatetimeWithNanoseconds(1980, 6, 4, 0, 0, tzinfo=<UTC>),
#    'last_name': 'Pappas'},
#   'other_ids': {'fec_id': 'H8NH01210',
#    'govtrack_id': '412795',
#    'crp_id': 'N00042161',
#    'votesmart_id': '42635',
#    'google_id': '/m/0nd3t8z',
#    'cspan_id': None},
#   '_id': 'P000614',
#   'activity': {'in_office': True,
#    'last_updated': DatetimeWithNanoseconds(2021, 1, 28, 0, 0, tzinfo=<UTC>)},
#   'roles': [{'party': 'D',
#     'ocd_id': 'ocd-division/country:us/state:nh/cd:1',
#     'phone': '202-225-5456',
#     'bills_sponsored': 0,
#     'senate_class': '',
#     'total_votes': 18,
#     'fax': None,
#     'votes_against_party_pct': 0.0,
#     'fec_candidate_id': 'H8NH01210',
#     'title': 'Representative',
#     'next_election': '2022',
#     'ideal_point': None,
#     'short_title': 'Rep.',
#     'votes_with_party_pct': 94.12,
#     'chamber': 'House',
#     'state_rank': '',
#     'contact_form': None,
#     'state': 'NH',
#     'at_large': False,
#     'subcommittees': [],
#     'committees': [],
#     'bills_cosponsored': 12,
#     'total_present': 0,
#     'missed_votes_pct': 0.0,
#     'district': '1',
#     'congress': '117',
#     'leadership_role': None,
#     'dw_nominate': None,
#     'lis_id': '',
#     'missed_votes': 0,
#     'start_date': '2021-01-03',
#     'end_date': '2023-01-03',
#     'office': '319 Cannon House Office Building',
#     'seniority': '4',
#     'cook_pvi': None},
#    {'at_large': False,
#     'next_election': '2020',
#     'short_title': 'Rep.',
#     'senate_class': '',
#     'seniority': '2',
#     'total_votes': 954,
#     'subcommittees': [{'code': 'HSVR08',
#       'parent_committee_id': 'HSVR',
#       'side': 'majority',
#       'title': 'Chair',
#       'name': 'Oversight and Investigations',
#       'begin_date': '2019-01-31',
#       'end_date': '2021-01-03',
#       'rank_in_party': 1,
#       'api_uri': 'https://api.propublica.org/congress/v1/116/house/committees/HSVR/subcommittees/HSVR08.json'},
#      {'parent_committee_id': 'HSVR',
#       'side': 'majority',
#       'code': 'HSVR10',
#       'begin_date': '2019-01-31',
#       'end_date': '2021-01-03',
#       'name': 'Economic Opportunity',
#       'api_uri': 'https://api.propublica.org/congress/v1/116/house/committees/HSVR/subcommittees/HSVR10.json',
#       'title': 'Member',
#       'rank_in_party': 4},
#      {'begin_date': '',
#       'rank_in_party': 8,
#       'code': 'HSPW07',
#       'title': 'Member',
#       'name': 'Coast Guard and Maritime Transportation',
#       'end_date': '2021-01-03',
#       'side': 'majority',
#       'api_uri': 'https://api.propublica.org/congress/v1/116/house/committees/HSPW/subcommittees/HSPW07.json',
#       'parent_committee_id': 'HSPW'},
#      {'api_uri': 'https://api.propublica.org/congress/v1/116/house/committees/HSPW/subcommittees/HSPW12.json',
#       'side': 'majority',
#       'end_date': '2021-01-03',
#       'parent_committee_id': 'HSPW',
#       'rank_in_party': 21,
#       'title': 'Member',
#       'code': 'HSPW12',
#       'name': 'Highways and Transit',
#       'begin_date': ''},
#      {'api_uri': 'https://api.propublica.org/congress/v1/116/house/committees/HSPW/subcommittees/HSPW02.json',
#       'title': 'Member',
#       'rank_in_party': 12,
#       'name': 'Water Resources and Environment',
#       'side': 'majority',
#       'parent_committee_id': 'HSPW',
#       'code': 'HSPW02',
#       'begin_date': '',
#       'end_date': '2021-01-03'}],
#     'lis_id': '',
#     'cook_pvi': 'R+2',
#     'end_date': '2021-01-03',
#     'votes_against_party_pct': 2.63,
#     'missed_votes_pct': 0.1,
#     'ideal_point': None,
#     'contact_form': None,
#     'leadership_role': None,
#     'total_present': 0,
#     'congress': '116',
#     'committees': [{'end_date': '2021-01-03',
#       'title': 'Member',
#       'api_uri': 'https://api.propublica.org/congress/v1/116/house/committees/HSVR.json',
#       'begin_date': '2019-01-17',
#       'code': 'HSVR',
#       'side': 'majority',
#       'name': "Committee on Veterans' Affairs",
#       'rank_in_party': 7},
#      {'name': 'Committee on Transportation and Infrastructure',
#       'code': 'HSPW',
#       'begin_date': '2017-01-17',
#       'api_uri': 'https://api.propublica.org/congress/v1/116/house/committees/HSPW.json',
#       'rank_in_party': 35,
#       'title': 'Member',
#       'end_date': '2021-01-03',
#       'side': 'majority'}],
#     'title': 'Representative',
#     'votes_with_party_pct': 97.27,
#     'district': '1',
#     'chamber': 'House',
#     'missed_votes': 1,
#     'fec_candidate_id': 'H8NH01210',
#     'start_date': '2019-01-03',
#     'bills_cosponsored': 615,
#     'phone': '202-225-5456',
#     'state_rank': '',
#     'fax': None,
#     'bills_sponsored': 37,
#     'state': 'NH',
#     'party': 'D',
#     'dw_nominate': None,
#     'ocd_id': 'ocd-division/country:us/state:nh/cd:1',
#     'office': '323 Cannon House Office Building'}]},
#  {'roles': [{'ocd_id': 'ocd-division/country:us/state:mo/cd:8',
#     'missed_votes': 0,
#     'total_votes': 18,
#     'phone': '202-225-4404',
#     'district': '8',
#     'seniority': '10',
#     'votes_with_party_pct': 88.24,
#     'bills_sponsored': 0,
#     'next_election': '2022',
#     'cook_pvi': None,
#     'fax': None,
#     'committees': [],
#     'end_date': '2023-01-03',
#     'subcommittees': [],
#     'leadership_role': None,
#     'office': '2418 Rayburn House Office Building',
#     'at_large': False,
#     'dw_nominate': 0.601,
#     'chamber': 'House',
#     'state_rank': '',
#     'contact_form': None,
#     'title': 'Representative',
#     'votes_against_party_pct': 5.88,
#     'short_title': 'Rep.',
#     'fec_candidate_id': 'H4MO08162',
#     'party': 'R',
#     'lis_id': '',
#     'state': 'MO',
#     'start_date': '2021-01-03',
#     'bills_cosponsored': 4,
#     'senate_class': '',
#     'ideal_point': None,
#     'missed_votes_pct': 0.0,
#     'congress': '117',
#     'total_present': 0},
#    {'office': '2418 Rayburn House Office Building',
#     'total_votes': 954,
#     'bills_cosponsored': 203,
#     'dw_nominate': 0.602,
#     'short_title': 'Rep.',
#     'end_date': '2021-01-03',
#     'committees': [{'rank_in_party': 4,
#       'api_uri': 'https://api.propublica.org/congress/v1/116/house/committees/HSBU.json',
#       'name': 'Committee on the Budget',
#       'end_date': '2021-01-03',
#       'title': 'Member',
#       'side': 'minority',
#       'begin_date': '2019-01-24',
#       'code': 'HSBU'},
#      {'api_uri': 'https://api.propublica.org/congress/v1/116/house/committees/HSWM.json',
#       'name': 'Committee on Ways and Means',
#       'rank_in_party': 9,
#       'side': 'minority',
#       'title': 'Member',
#       'code': 'HSWM',
#       'end_date': '2021-01-03',
#       'begin_date': ''}],
#     'missed_votes_pct': 0.31,
#     'total_present': 0,
#     'senate_class': '',
#     'next_election': '2020',
#     'votes_with_party_pct': 95.22,
#     'lis_id': '',
#     'congress': '116',
#     'leadership_role': None,
#     'district': '8',
#     'votes_against_party_pct': 4.67,
#     'chamber': 'House',
#     'fec_candidate_id': 'H4MO08162',
#     'state_rank': '',
#     'seniority': '8',
#     'phone': '202-225-4404',
#     'ideal_point': None,
#     'fax': None,
#     'ocd_id': 'ocd-division/country:us/state:mo/cd:8',
#     'missed_votes': 3,
#     'party': 'R',
#     'contact_form': None,
#     'bills_sponsored': 20,
#     'start_date': '2019-01-03',
#     'title': 'Representative',
#     'at_large': False,
#     'cook_pvi': 'R+24',
#     'subcommittees': [{'name': 'Trade',
#       'side': 'minority',
#       'rank_in_party': 6,
#       'title': 'Member',
#       'code': 'HSWM04',
#       'api_uri': 'https://api.propublica.org/congress/v1/116/house/committees/HSWM/subcommittees/HSWM04.json',
#       'parent_committee_id': 'HSWM',
#       'begin_date': '2019-01-16',
#       'end_date': '2021-01-03'}],
#     'state': 'MO'},
#    {'next_election': '2018',
#     'title': 'Representative',
#     'total_present': 0,
#     'fec_candidate_id': 'H4MO08162',
#     'congress': '115',
#     'short_title': 'Rep.',
#     'phone': '202-225-4404',
#     'leadership_role': None,
#     'committees': [{'code': 'HSBU',
#       'begin_date': '',
#       'end_date': '2019-01-03',
#       'api_uri': 'https://api.propublica.org/congress/v1/115/house/committees/HSBU.json',
#       'name': 'Committee on the Budget',
#       'title': 'Member',
#       'side': 'majority',
#       'rank_in_party': 15},
#      {'code': 'HSWM',
#       'title': 'Member',
#       'end_date': '2019-01-03',
#       'rank_in_party': 17,
#       'side': 'majority',
#       'name': 'Committee on Ways and Means',
#       'api_uri': 'https://api.propublica.org/congress/v1/115/house/committees/HSWM.json',
#       'begin_date': ''}],
#     'end_date': '2019-01-03',
#     'senate_class': '',
#     'at_large': False,
#     'votes_with_party_pct': 95.84,
#     'ideal_point': None,
#     'state_rank': '',
#     'seniority': '6',
#     'district': '8',
#     'votes_against_party_pct': 4.16,
#     'bills_sponsored': 25,
#     'ocd_id': 'ocd-division/country:us/state:mo/cd:8',
#     'contact_form': None,
#     'party': 'R',
#     'start_date': '2017-01-03',
#     'missed_votes': 27,
#     'bills_cosponsored': 199,
#     'dw_nominate': 0.618,
#     'state': 'MO',
#     'office': '1118 Longworth House Office Building',
#     'fax': '202-226-0326',
#     'cook_pvi': None,
#     'lis_id': '',
#     'total_votes': 1211,
#     'chamber': 'House',
#     'subcommittees': [{'title': 'Member',
#       'code': 'HSWM05',
#       'end_date': '2019-01-03',
#       'rank_in_party': 9,
#       'parent_committee_id': 'HSWM',
#       'api_uri': 'https://api.propublica.org/congress/v1/115/house/committees/HSWM/subcommittees/HSWM05.json',
#       'side': 'majority',
#       'name': 'Select Revenue Measures',
#       'begin_date': ''},
#      {'parent_committee_id': 'HSWM',
#       'begin_date': '',
#       'side': 'majority',
#       'api_uri': 'https://api.propublica.org/congress/v1/115/house/committees/HSWM/subcommittees/HSWM01.json',
#       'title': 'Member',
#       'rank_in_party': 5,
#       'end_date': '2019-01-03',
#       'name': 'Social Security',
#       'code': 'HSWM01'},
#      {'end_date': '2018-03-06',
#       'parent_committee_id': 'HSWM',
#       'code': 'HSWM03',
#       'name': 'Worker and Family Support',
#       'api_uri': 'https://api.propublica.org/congress/v1/115/house/committees/HSWM/subcommittees/HSWM03.json',
#       'rank_in_party': None,
#       'side': 'majority',
#       'begin_date': '',
#       'title': 'Member'}],
#     'missed_votes_pct': 2.23},
#    {'fec_candidate_id': 'H4MO08162',
#     'contact_form': None,
#     'short_title': 'Rep.',
#     'bills_cosponsored': 161,
#     'phone': None,
#     'chamber': 'House',
#     'missed_votes': 12,
#     'end_date': '2017-01-03',
#     'start_date': '2015-01-06',
#     'subcommittees': [],
#     'party': 'R',
#     'state_rank': '',
#     'cook_pvi': None,
#     'next_election': '2016',
#     'committees': [{'end_date': '2017-01-03',
#       'begin_date': '',
#       'rank_in_party': 22,
#       'code': 'HSWM',
#       'api_uri': 'https://api.propublica.org/congress/v1/114/house/committees/HSWM.json',
#       'name': 'Committee on Ways and Means'}],
#     'title': 'Representative',
#     'senate_class': '',
#     'seniority': '4',
#     'missed_votes_pct': 0.91,
#     'ideal_point': None,
#     'state': 'MO',
#     'total_present': 0,
#     'total_votes': 1325,
#     'bills_sponsored': 10,
#     'votes_against_party_pct': 3.53,
#     'district': '8',
#     'fax': None,
#     'votes_with_party_pct': 96.39,
#     'ocd_id': 'ocd-division/country:us/state:mo/cd:8',
#     'lis_id': '',
#     'dw_nominate': 0.61,
#     'congress': '114',
#     'office': None,
#     'leadership_role': None,
#     'at_large': False},
#    {'bills_cosponsored': 149,
#     'votes_against_party_pct': 3.52,
#     'votes_with_party_pct': 96.48,
#     'contact_form': None,
#     'fax': None,
#     'missed_votes': 8,
#     'title': 'Representative',
#     'end_date': '2015-01-03',
#     'lis_id': '',
#     'dw_nominate': 0.61,
#     'missed_votes_pct': 0.79,
#     'next_election': '',
#     'at_large': False,
#     'seniority': '2',
#     'ocd_id': 'ocd-division/country:us/state:mo/cd:8',
#     'fec_candidate_id': '',
#     'phone': None,
#     'committees': [{'code': 'HSJU',
#       'end_date': '2015-01-03',
#       'rank_in_party': 23,
#       'api_uri': 'https://api.propublica.org/congress/v1/113/house/committees/HSJU.json',
#       'name': 'Committee on the Judiciary',
#       'begin_date': '2013-06-12'},
#      {'api_uri': 'https://api.propublica.org/congress/v1/113/house/committees/HSII.json',
#       'name': 'Committee on Natural Resources',
#       'rank_in_party': 26,
#       'begin_date': '2013-06-12',
#       'end_date': '2015-01-03',
#       'code': 'HSII'}],
#     'start_date': '2013-06-05',
#     'party': 'R',
#     'chamber': 'House',
#     'total_votes': 1007,
#     'bills_sponsored': 4,
#     'office': None,
#     'state_rank': '',
#     'senate_class': '',
#     'total_present': 0,
#     'congress': '113',
#     'subcommittees': [],
#     'cook_pvi': None,
#     'short_title': 'Rep.',
#     'ideal_point': 1.29445928,
#     'district': '8',
#     'leadership_role': None,
#     'state': 'MO'}],
#   'bio': {'middle_name': '',
#    'first_name': 'Jason',
#    'gender': 'M',
#    'last_name': 'Smith',
#    'current_party': 'R',
#    'dob': DatetimeWithNanoseconds(1980, 6, 16, 0, 0, tzinfo=<UTC>)},
#   'other_ids': {'cspan_id': '71083',
#    'crp_id': 'N00035282',
#    'votesmart_id': '59318',
#    'govtrack_id': '412596',
#    'google_id': '/m/0g9yj_2',
#    'fec_id': 'H4MO08162'},
#   'activity': {'in_office': True,
#    'last_updated': DatetimeWithNanoseconds(2021, 1, 28, 0, 0, tzinfo=<UTC>)},
#   '_id': 'S001195'},
#  {'bio': {'first_name': 'Brian',
#    'current_party': 'R',
#    'middle_name': None,
#    'dob': DatetimeWithNanoseconds(1980, 7, 10, 0, 0, tzinfo=<UTC>),
#    'last_name': 'Mast',
#    'gender': 'M'},
#   'activity': {'in_office': True,
#    'last_updated': DatetimeWithNanoseconds(2021, 1, 28, 0, 0, tzinfo=<UTC>)},
#   'roles': [{'congress': '117',
#     'ocd_id': 'ocd-division/country:us/state:fl/cd:18',
#     'ideal_point': None,
#     'phone': '202-225-3026',
#     'committees': [],
#     'state': 'FL',
#     'total_present': 0,
#     'cook_pvi': None,
#     'title': 'Representative',
#     'bills_cosponsored': 8,
#     'next_election': '2022',
#     'bills_sponsored': 1,
#     'office': '2182 Rayburn House Office Building',
#     'seniority': '6',
#     'fec_candidate_id': 'H6FL18097',
#     'fax': None,
#     'at_large': False,
#     'contact_form': None,
#     'senate_class': '',
#     'subcommittees': [],
#     'start_date': '2021-01-03',
#     'missed_votes_pct': 0.0,
#     'lis_id': '',
#     'total_votes': 18,
#     'chamber': 'House',
#     'dw_nominate': 0.423,
#     'votes_with_party_pct': 94.12,
#     'short_title': 'Rep.',
#     'state_rank': '',
#     'votes_against_party_pct': 0.0,
#     'end_date': '2023-01-03',
#     'leadership_role': None,
#     'district': '18',
#     'missed_votes': 0,
#     'party': 'R'},
#    {'congress': '116',
#     'state': 'FL',
#     'leadership_role': None,
#     'missed_votes_pct': 5.03,
#     'lis_id': '',
#     'office': '2182 Rayburn House Office Building',
#     'dw_nominate': 0.422,
#     'total_present': 0,
#     'fax': None,
#     'party': 'R',
#     'cook_pvi': 'R+5',
#     'bills_sponsored': 21,
#     'subcommittees': [{'end_date': '2021-01-03',
#       'side': 'minority',
#       'parent_committee_id': 'HSFA',
#       'api_uri': 'https://api.propublica.org/congress/v1/116/house/committees/HSFA/subcommittees/HSFA05.json',
#       'name': 'Asia, the Pacific, and Nonproliferation',
#       'code': 'HSFA05',
#       'rank_in_party': 4,
#       'begin_date': '2019-01-29',
#       'title': 'Member'},
#      {'title': 'Member',
#       'api_uri': 'https://api.propublica.org/congress/v1/116/house/committees/HSFA/subcommittees/HSFA13.json',
#       'end_date': '2021-01-03',
#       'side': 'minority',
#       'name': 'Middle East, North Africa, and International Terrorism',
#       'begin_date': '2019-01-29',
#       'parent_committee_id': 'HSFA',
#       'code': 'HSFA13',
#       'rank_in_party': 5},
#      {'name': 'Water Resources and Environment',
#       'begin_date': '',
#       'rank_in_party': 11,
#       'end_date': '2021-01-03',
#       'title': 'Member',
#       'code': 'HSPW02',
#       'side': 'minority',
#       'parent_committee_id': 'HSPW',
#       'api_uri': 'https://api.propublica.org/congress/v1/116/house/committees/HSPW/subcommittees/HSPW02.json'},
#      {'name': 'Aviation',
#       'api_uri': 'https://api.propublica.org/congress/v1/116/house/committees/HSPW/subcommittees/HSPW05.json',
#       'title': 'Member',
#       'side': 'minority',
#       'begin_date': '',
#       'rank_in_party': 11,
#       'code': 'HSPW05',
#       'parent_committee_id': 'HSPW',
#       'end_date': '2021-01-03'},
#      {'side': 'minority',
#       'parent_committee_id': 'HSPW',
#       'end_date': '2021-01-03',
#       'title': 'Member',
#       'begin_date': '',
#       'api_uri': 'https://api.propublica.org/congress/v1/116/house/committees/HSPW/subcommittees/HSPW07.json',
#       'rank_in_party': 4,
#       'code': 'HSPW07',
#       'name': 'Coast Guard and Maritime Transportation'}],
#     'ocd_id': 'ocd-division/country:us/state:fl/cd:18',
#     'next_election': '2020',
#     'bills_cosponsored': 312,
#     'ideal_point': None,
#     'phone': '202-225-3026',
#     'contact_form': None,
#     'seniority': '4',
#     'district': '18',
#     'total_votes': 954,
#     'short_title': 'Rep.',
#     'title': 'Representative',
#     'state_rank': '',
#     'end_date': '2021-01-03',
#     'fec_candidate_id': 'H6FL18097',
#     'start_date': '2019-01-03',
#     'missed_votes': 48,
#     'senate_class': '',
#     'votes_with_party_pct': 87.18,
#     'votes_against_party_pct': 12.71,
#     'at_large': False,
#     'committees': [{'end_date': '2021-01-03',
#       'title': 'Member',
#       'api_uri': 'https://api.propublica.org/congress/v1/116/house/committees/HSFA.json',
#       'name': 'Committee on Foreign Affairs',
#       'begin_date': '2019-01-23',
#       'rank_in_party': 11,
#       'code': 'HSFA',
#       'side': 'minority'},
#      {'end_date': '2021-01-03',
#       'side': 'minority',
#       'code': 'HSPW',
#       'api_uri': 'https://api.propublica.org/congress/v1/116/house/committees/HSPW.json',
#       'begin_date': '2019-01-23',
#       'name': 'Committee on Transportation and Infrastructure',
#       'rank_in_party': 21,
#       'title': 'Member'}],
#     'chamber': 'House'},
#    {'seniority': '2',
#     'chamber': 'House',
#     'missed_votes_pct': 0.91,
#     'contact_form': None,
#     'leadership_role': None,
#     'at_large': False,
#     'party': 'R',
#     'bills_cosponsored': 241,
#     'committees': [{'end_date': '2019-01-03',
#       'rank_in_party': 13,
#       'api_uri': 'https://api.propublica.org/congress/v1/115/house/committees/HSVR.json',
#       'begin_date': '2018-05-16',
#       'name': "Committee on Veterans' Affairs",
#       'code': 'HSVR',
#       'side': 'majority',
#       'title': 'Member'},
#      {'end_date': '2019-01-03',
#       'side': 'majority',
#       'api_uri': 'https://api.propublica.org/congress/v1/115/house/committees/HSFA.json',
#       'code': 'HSFA',
#       'title': 'Member',
#       'rank_in_party': 22,
#       'name': 'Committee on Foreign Affairs',
#       'begin_date': ''},
#      {'name': 'Committee on Transportation and Infrastructure',
#       'rank_in_party': 32,
#       'code': 'HSPW',
#       'side': 'majority',
#       'title': 'Member',
#       'end_date': '2019-01-03',
#       'begin_date': '',
#       'api_uri': 'https://api.propublica.org/congress/v1/115/house/committees/HSPW.json'}],
#     'end_date': '2019-01-03',
#     'senate_class': '',
#     'cook_pvi': None,
#     'fax': None,
#     'congress': '115',
#     'total_votes': 1211,
#     'ocd_id': 'ocd-division/country:us/state:fl/cd:18',
#     'subcommittees': [{'code': 'HSFA13',
#       'begin_date': '',
#       'rank_in_party': 10,
#       'parent_committee_id': 'HSFA',
#       'name': 'Middle East, North Africa, and International Terrorism',
#       'end_date': '2019-01-03',
#       'side': 'majority',
#       'title': 'Member',
#       'api_uri': 'https://api.propublica.org/congress/v1/115/house/committees/HSFA/subcommittees/HSFA13.json'},
#      {'begin_date': '',
#       'end_date': '2019-01-03',
#       'name': 'Oversight and Investigations',
#       'side': 'majority',
#       'api_uri': 'https://api.propublica.org/congress/v1/115/house/committees/HSFA/subcommittees/HSFA18.json',
#       'rank_in_party': 7,
#       'code': 'HSFA18',
#       'parent_committee_id': 'HSFA',
#       'title': 'Member'},
#      {'title': 'Member',
#       'side': 'majority',
#       'code': 'HSPW02',
#       'name': 'Water Resources and Environment',
#       'end_date': '2019-01-03',
#       'begin_date': '',
#       'api_uri': 'https://api.propublica.org/congress/v1/115/house/committees/HSPW/subcommittees/HSPW02.json',
#       'rank_in_party': 17,
#       'parent_committee_id': 'HSPW'},
#      {'rank_in_party': 7,
#       'end_date': '2019-01-03',
#       'api_uri': 'https://api.propublica.org/congress/v1/115/house/committees/HSPW/subcommittees/HSPW07.json',
#       'side': 'majority',
#       'title': 'Member',
#       'code': 'HSPW07',
#       'parent_committee_id': 'HSPW',
#       'name': 'Coast Guard and Maritime Transportation',
#       'begin_date': ''},
#      {'title': 'Member',
#       'end_date': '2019-01-03',
#       'begin_date': '',
#       'name': 'Economic Development, Public Buildings, and Emergency Management',
#       'parent_committee_id': 'HSPW',
#       'code': 'HSPW13',
#       'side': 'majority',
#       'rank_in_party': 8,
#       'api_uri': 'https://api.propublica.org/congress/v1/115/house/committees/HSPW/subcommittees/HSPW13.json'}],
#     'start_date': '2017-01-03',
#     'state': 'FL',
#     'phone': '202-225-3026',
#     'dw_nominate': 0.333,
#     'office': '2182 Rayburn House Office Building',
#     'bills_sponsored': 20,
#     'votes_with_party_pct': 90.79,
#     'state_rank': '',
#     'total_present': 0,
#     'district': '18',
#     'short_title': 'Rep.',
#     'next_election': '2018',
#     'title': 'Representative',
#     'missed_votes': 11,
#     'lis_id': '',
#     'votes_against_party_pct': 9.21,
#     'ideal_point': None,
#     'fec_candidate_id': 'H6FL18097'}],
#   '_id': 'M001199',
#   'other_ids': {'fec_id': 'H6FL18097',
#    'cspan_id': '104540',
#    'govtrack_id': '412698',
#    'google_id': '/g/11cs5xxx_f',
#    'votesmart_id': '166245',
#    'crp_id': 'N00037269'}},
#  {'other_ids': {'cspan_id': '79948',
#    'google_id': '/m/0j28kl9',
#    'govtrack_id': '412543',
#    'crp_id': 'N00034044',
#    'votesmart_id': '141275',
#    'fec_id': 'H2MA04073'},
#   'roles': [{'total_present': 0,
#     'missed_votes_pct': 2.52,
#     'title': 'Representative',
#     'next_election': '2020',
#     'office': '304 Cannon House Office Building',
#     'short_title': 'Rep.',
#     'congress': '116',
#     'cook_pvi': 'D+9',
#     'contact_form': None,
#     'bills_cosponsored': 685,
#     'votes_against_party_pct': 1.83,
#     'start_date': '2019-01-03',
#     'end_date': '2021-01-03',
#     'ideal_point': None,
#     'bills_sponsored': 34,
#     'at_large': False,
#     'leadership_role': None,
#     'phone': '202-225-5931',
#     'seniority': '8',
#     'subcommittees': [{'rank_in_party': 3,
#       'title': 'Member',
#       'api_uri': 'https://api.propublica.org/congress/v1/116/house/committees/HSIF/subcommittees/HSIF02.json',
#       'end_date': '2021-01-03',
#       'name': 'Oversight and Investigations',
#       'side': 'majority',
#       'begin_date': '2019-01-15',
#       'parent_committee_id': 'HSIF',
#       'code': 'HSIF02'},
#      {'code': 'HSIF03',
#       'api_uri': 'https://api.propublica.org/congress/v1/116/house/committees/HSIF/subcommittees/HSIF03.json',
#       'title': 'Member',
#       'parent_committee_id': 'HSIF',
#       'side': 'majority',
#       'end_date': '2021-01-03',
#       'begin_date': '2019-01-15',
#       'name': 'Energy',
#       'rank_in_party': 11},
#      {'name': 'Health',
#       'parent_committee_id': 'HSIF',
#       'end_date': '2021-01-03',
#       'api_uri': 'https://api.propublica.org/congress/v1/116/house/committees/HSIF/subcommittees/HSIF14.json',
#       'begin_date': '2019-01-15',
#       'rank_in_party': 9,
#       'title': 'Member',
#       'side': 'majority',
#       'code': 'HSIF14'}],
#     'committees': [{'side': 'majority',
#       'begin_date': '2019-01-15',
#       'title': 'Member',
#       'api_uri': 'https://api.propublica.org/congress/v1/116/house/committees/HSIF.json',
#       'code': 'HSIF',
# ...
#       'parent_committee_id': 'HSIG',
#       'title': 'Chair',
#       'code': 'HSIG08',
#       'rank_in_party': 1,
#       'name': 'Intelligence Modernization and Readiness',
#       'side': 'majority',
#       'end_date': '2021-01-03',
#       'begin_date': ''},
#      {'rank_in_party': 5,
#       'end_date': '2021-01-03',
#       'title': 'Member',
#       'api_uri': 'https://api.propublica.org/congress/v1/116/house/committees/HSIG/subcommittees/HSIG10.json',
#       'parent_committee_id': 'HSIG',
#       'code': 'HSIG10',
#       'name': 'Strategic Technologies and Advanced Research',
#       'side': 'majority',
#       'begin_date': ''}],
#     'dw_nominate': -0.368,
#     'next_election': '2020',
#     'committees': [{'name': 'Committee on the Judiciary',
#       'end_date': '2021-01-03',
#       'rank_in_party': 11,
#       'begin_date': '2019-01-16',
#       'api_uri': 'https://api.propublica.org/congress/v1/116/house/committees/HSJU.json',
#       'side': 'majority',
#       'code': 'HSJU',
#       'title': 'Member'},
#      {'code': 'HSIG',
#       'begin_date': '2019-01-16',
#       'rank_in_party': 7,
#       'name': 'Permanent Select Committee on Intelligence',
#       'api_uri': 'https://api.propublica.org/congress/v1/116/house/committees/HSIG.json',
#       'title': 'Member',
#       'side': 'majority',
#       'end_date': '2021-01-03'}],
#     'phone': '202-225-5065',
#     'bills_sponsored': 21,
#     'district': '15',
#     'bills_cosponsored': 551,
#     'office': '407 Cannon House Office Building',
#     'fax': None,
#     'cook_pvi': 'D+20',
#     'total_present': 0,
#     'fec_candidate_id': 'H2CA15094',
#     'title': 'Representative',
#     'missed_votes': 207,
#     'votes_against_party_pct': 0.94,
#     'state': 'CA',
#     'lis_id': '',
#     'end_date': '2021-01-03',
#     'total_votes': 954,
#     'start_date': '2019-01-03',
#     'chamber': 'House',
#     'short_title': 'Rep.',
#     'ocd_id': 'ocd-division/country:us/state:ca/cd:15'},
#    {'votes_against_party_pct': 3.36,
#     'party': 'D',
#     'next_election': '2018',
#     'short_title': 'Rep.',
#     'missed_votes': 78,
#     'seniority': '6',
#     'dw_nominate': -0.364,
#     'bills_cosponsored': 482,
#     'fax': None,
#     'ocd_id': 'ocd-division/country:us/state:ca/cd:15',
#     'leadership_role': None,
#     'title': 'Representative',
#     'bills_sponsored': 15,
#     'start_date': '2017-01-03',
#     'phone': '202-225-5065',
#     'cook_pvi': None,
#     'total_votes': 1211,
#     'office': '129 Cannon House Office Building',
#     'subcommittees': [{'begin_date': '',
#       'end_date': '2019-01-03',
#       'name': 'Central Intelligence Agency',
#       'parent_committee_id': 'HSIG',
#       'side': 'minority',
#       'code': 'HSIG01',
#       'title': 'Ranking Member',
#       'rank_in_party': 1,
#       'api_uri': 'https://api.propublica.org/congress/v1/115/house/committees/HSIG/subcommittees/HSIG01.json'},
#      {'end_date': '2019-01-03',
#       'side': 'minority',
#       'api_uri': 'https://api.propublica.org/congress/v1/115/house/committees/HSIG/subcommittees/HSIG03.json',
#       'title': 'Member',
#       'begin_date': '',
#       'parent_committee_id': 'HSIG',
#       'name': 'Emerging Threats',
#       'code': 'HSIG03',
#       'rank_in_party': 4},
#      {'code': 'HSJU03',
#       'parent_committee_id': 'HSJU',
#       'begin_date': '',
#       'title': 'Member',
#       'name': 'Courts, Intellectual Property, and the Internet',
#       'end_date': '2019-01-03',
#       'side': 'minority',
#       'rank_in_party': 6,
#       'api_uri': 'https://api.propublica.org/congress/v1/115/house/committees/HSJU/subcommittees/HSJU03.json'},
#      {'parent_committee_id': 'HSJU',
#       'title': 'Member',
#       'rank_in_party': 3,
#       'begin_date': '',
#       'side': 'minority',
#       'name': 'Antitrust, Commercial and Administrative Law',
#       'code': 'HSJU05',
#       'end_date': '2019-01-03',
#       'api_uri': 'https://api.propublica.org/congress/v1/115/house/committees/HSJU/subcommittees/HSJU05.json'}],
#     'contact_form': None,
#     'lis_id': '',
#     'total_present': 0,
#     'chamber': 'House',
#     'fec_candidate_id': 'H2CA15094',
#     'congress': '115',
#     'at_large': False,
#     'district': '15',
#     'senate_class': '',
#     'state': 'CA',
#     'votes_with_party_pct': 96.64,
#     'ideal_point': None,
#     'end_date': '2019-01-03',
#     'missed_votes_pct': 6.44,
#     'committees': [{'side': 'minority',
#       'title': 'Member',
#       'api_uri': 'https://api.propublica.org/congress/v1/115/house/committees/HSIG.json',
#       'begin_date': '',
#       'end_date': '2019-01-03',
#       'code': 'HSIG',
#       'name': 'Permanent Select Committee on Intelligence',
#       'rank_in_party': 7},
#      {'side': 'minority',
#       'rank_in_party': 12,
#       'begin_date': '',
#       'name': 'Committee on the Judiciary',
#       'title': 'Member',
#       'end_date': '2019-01-03',
#       'api_uri': 'https://api.propublica.org/congress/v1/115/house/committees/HSJU.json',
#       'code': 'HSJU'}],
#     'state_rank': ''},
#    {'chamber': 'House',
#     'fax': None,
#     'committees': [{'name': 'Permanent Select Committee on Intelligence',
#       'rank_in_party': 8,
#       'api_uri': 'https://api.propublica.org/congress/v1/114/house/committees/HSIG.json',
#       'begin_date': '',
#       'end_date': '2017-01-03',
#       'code': 'HSIG'},
#      {'name': 'Committee on Science, Space, and Technology',
#       'rank_in_party': 6,
#       'code': 'HSSY',
#       'api_uri': 'https://api.propublica.org/congress/v1/114/house/committees/HSSY.json',
#       'begin_date': '',
#       'end_date': '2017-01-03'}],
#     'votes_against_party_pct': 3.41,
#     'total_present': 0,
#     'leadership_role': None,
#     'subcommittees': [],
#     'district': '15',
#     'votes_with_party_pct': 96.51,
#     'next_election': '2016',
#     'phone': None,
#     'total_votes': 1325,
#     'congress': '114',
#     'seniority': '4',
#     'party': 'D',
#     'at_large': False,
#     'state_rank': '',
#     'bills_sponsored': 10,
#     'missed_votes_pct': 3.7,
#     'state': 'CA',
#     'end_date': '2017-01-03',
#     'title': 'Representative',
#     'ideal_point': None,
#     'bills_cosponsored': 417,
#     'office': None,
#     'dw_nominate': -0.365,
#     'ocd_id': 'ocd-division/country:us/state:ca/cd:15',
#     'short_title': 'Rep.',
#     'start_date': '2015-01-06',
#     'lis_id': '',
#     'contact_form': None,
#     'missed_votes': 49,
#     'senate_class': '',
#     'fec_candidate_id': 'H2CA15094',
#     'cook_pvi': None},
#    {'votes_with_party_pct': 93.52,
#     'missed_votes_pct': 0.5,
#     'congress': '113',
#     'total_present': 1,
#     'dw_nominate': -0.365,
#     'seniority': '2',
#     'cook_pvi': None,
#     'bills_sponsored': 9,
#     'start_date': '2013-01-03',
#     'committees': [{'begin_date': '2013-01-14',
#       'name': 'Committee on Homeland Security',
#       'rank_in_party': 14,
#       'api_uri': 'https://api.propublica.org/congress/v1/113/house/committees/HSHM.json',
#       'code': 'HSHM',
#       'end_date': '2015-01-03'},
#      {'code': 'HSSY',
#       'name': 'Committee on Science, Space, and Technology',
#       'rank_in_party': 7,
#       'end_date': '2015-01-03',
#       'api_uri': 'https://api.propublica.org/congress/v1/113/house/committees/HSSY.json',
#       'begin_date': '2013-01-03'}],
#     'next_election': '',
#     'senate_class': '',
#     'contact_form': None,
#     'total_votes': 1204,
#     'party': 'D',
#     'votes_against_party_pct': 6.4,
#     'at_large': False,
#     'office': None,
#     'district': '15',
#     'ocd_id': 'ocd-division/country:us/state:ca/cd:15',
#     'state_rank': '',
#     'short_title': 'Rep.',
#     'fec_candidate_id': '',
#     'lis_id': '',
#     'missed_votes': 6,
#     'state': 'CA',
#     'chamber': 'House',
#     'ideal_point': -0.913109618,
#     'subcommittees': [],
#     'end_date': '2015-01-03',
#     'fax': None,
#     'title': 'Representative',
#     'phone': None,
#     'leadership_role': None,
#     'bills_cosponsored': 367}]},
#  {'_id': 'S001204',
#   'other_ids': {'fec_id': '',
#    'crp_id': 'N00042619',
#    'votesmart_id': None,
#    'govtrack_id': '412770',
#    'google_id': None,
#    'cspan_id': None},
#   'activity': {'last_updated': DatetimeWithNanoseconds(2021, 1, 28, 0, 0, tzinfo=<UTC>),
#    'in_office': True},
#   'roles': [{'short_title': 'Del.',
#     'fax': None,
#     'next_election': '2022',
#     'bills_sponsored': 2,
#     'phone': None,
#     'end_date': '2023-01-03',
#     'ocd_id': 'ocd-division/country:us/state:gu/cd:79',
#     'cook_pvi': None,
#     'missed_votes': None,
#     'votes_with_party_pct': None,
#     'fec_candidate_id': '',
#     'ideal_point': None,
#     'state_rank': '',
#     'chamber': 'House',
#     'missed_votes_pct': None,
#     'start_date': '2021-01-03',
#     'committees': [],
#     'lis_id': '',
#     'contact_form': None,
#     'senate_class': '',
#     'title': 'Delegate',
#     'congress': '117',
#     'party': 'D',
#     'dw_nominate': None,
#     'district': 'At-Large',
#     'seniority': '4',
#     'votes_against_party_pct': None,
#     'bills_cosponsored': 4,
#     'subcommittees': [],
#     'total_present': None,
#     'leadership_role': None,
#     'state': 'GU',
#     'office': None,
#     'at_large': True,
#     'total_votes': None},
#    {'state': 'GU',
#     'ocd_id': 'ocd-division/country:us/state:gu/cd:79',
#     'at_large': True,
#     'missed_votes_pct': 50.63,
#     'state_rank': '',
#     'total_present': 0,
#     'contact_form': None,
#     'votes_against_party_pct': 0.64,
#     'title': 'Delegate',
#     'total_votes': 316,
#     'committees': [{'title': 'Member',
#       'api_uri': 'https://api.propublica.org/congress/v1/116/house/committees/HSII.json',
#       'side': 'majority',
#       'code': 'HSII',
#       'rank_in_party': 22,
#       'name': 'Committee on Natural Resources',
#       'begin_date': '2019-01-24',
#       'end_date': '2021-01-03'},
#      {'begin_date': '2019-01-17',
#       'api_uri': 'https://api.propublica.org/congress/v1/116/house/committees/HSBA.json',
#       'code': 'HSBA',
#       'side': 'majority',
#       'name': 'Committee on Financial Services',
#       'title': 'Member',
#       'end_date': '2021-01-03',
#       'rank_in_party': 19}],
#     'dw_nominate': None,
#     'office': '1632 Longworth House Office Building',
#     'fec_candidate_id': '',
#     'senate_class': '',
#     'leadership_role': None,
#     'seniority': '2',
#     'short_title': 'Del.',
#     'phone': '202-225-1188',
#     'district': 'At-Large',
#     'fax': None,
#     'chamber': 'House',
#     'end_date': '2021-01-03',
#     'ideal_point': None,
#     'bills_sponsored': 16,
#     'votes_with_party_pct': 99.36,
#     'start_date': '2019-01-03',
#     'party': 'D',
#     'lis_id': '',
#     'congress': '116',
#     'cook_pvi': None,
#     'bills_cosponsored': 424,
#     'subcommittees': [{'begin_date': '2019-01-30',
#       'side': 'majority',
#       'end_date': '2021-01-03',
#       'code': 'HSII15',
#       'rank_in_party': 4,
#       'parent_committee_id': 'HSII',
#       'title': 'Member',
#       'name': 'Oversight and Investigations',
#       'api_uri': 'https://api.propublica.org/congress/v1/116/house/committees/HSII/subcommittees/HSII15.json'},
#      {'begin_date': '',
#       'code': 'HSBA01',
#       'name': 'National Security, International Development, and Monetary Policy',
#       'api_uri': 'https://api.propublica.org/congress/v1/116/house/committees/HSBA/subcommittees/HSBA01.json',
#       'parent_committee_id': 'HSBA',
#       'rank_in_party': 8,
#       'title': 'Member',
#       'side': 'majority',
#       'end_date': '2021-01-03'},
#      {'side': 'majority',
#       'parent_committee_id': 'HSII',
#       'api_uri': 'https://api.propublica.org/congress/v1/116/house/committees/HSII/subcommittees/HSII24.json',
#       'name': 'Indigenous Peoples of the United States',
#       'end_date': '2021-01-03',
#       'rank_in_party': 3,
#       'begin_date': '',
#       'code': 'HSII24',
#       'title': 'Member'},
#      {'parent_committee_id': 'HSBA',
#       'code': 'HSBA16',
#       'rank_in_party': 10,
#       'end_date': '2021-01-03',
#       'begin_date': '',
#       'title': 'Member',
#       'api_uri': 'https://api.propublica.org/congress/v1/116/house/committees/HSBA/subcommittees/HSBA16.json',
#       'side': 'majority',
#       'name': 'Investor Protection, Entrepreneurship, and Capital Markets'}],
#     'missed_votes': 160,
#     'next_election': '2020'}],
#   'bio': {'first_name': 'Michael',
#    'last_name': 'San Nicolas',
#    'current_party': 'D',
#    'gender': 'M',
#    'middle_name': None,
#    'dob': DatetimeWithNanoseconds(1981, 1, 30, 0, 0, tzinfo=<UTC>)}},
#  {'activity': {'in_office': True,
#    'last_updated': DatetimeWithNanoseconds(2021, 1, 28, 0, 0, tzinfo=<UTC>)},
#   'roles': [{'phone': '202-225-3031',
#     'cook_pvi': None,
#     'title': 'Representative',
#     'fax': None,
#     'start_date': '2021-01-03',
#     'state_rank': '',
#     'party': 'R',
#     'end_date': '2023-01-03',
#     'state': 'WI',
#     'total_votes': 18,
#     'bills_sponsored': 1,
#     'senate_class': '',
#     'ideal_point': None,
#     'lis_id': '',
#     'missed_votes_pct': 0.0,
#     'committees': [],
#     'seniority': '4',
#     'missed_votes': 0,
#     'votes_against_party_pct': 17.65,
#     'next_election': '2022',
#     'fec_candidate_id': 'H8WI01156',
#     'bills_cosponsored': 3,
#     'dw_nominate': None,
#     'votes_with_party_pct': 76.47,
#     'district': '1',
#     'subcommittees': [],
#     'ocd_id': 'ocd-division/country:us/state:wi/cd:1',
#     'leadership_role': None,
#     'chamber': 'House',
#     'contact_form': None,
#     'total_present': 0,
#     'office': '1526 Longworth House Office Building',
#     'congress': '117',
#     'short_title': 'Rep.',
#     'at_large': False},
#    {'fax': None,
#     'lis_id': '',
#     'district': '1',
#     'office': '1408 Longworth House Office Building',
#     'senate_class': '',
#     'leadership_role': None,
#     'next_election': '2020',
#     'phone': '202-225-3031',
#     'total_present': 0,
#     'party': 'R',
#     'committees': [{'code': 'HSBA',
#       'begin_date': '2019-01-23',
#       'api_uri': 'https://api.propublica.org/congress/v1/116/house/committees/HSBA.json',
#       'rank_in_party': 22,
#       'name': 'Committee on Financial Services',
#       'side': 'minority',
#       'end_date': '2021-01-03',
#       'title': 'Member'}],
#     'at_large': False,
#     'bills_cosponsored': 145,
#     'votes_against_party_pct': 7.72,
#     'ideal_point': None,
#     'state_rank': '',
#     'start_date': '2019-01-03',
#     'seniority': '2',
#     'dw_nominate': None,
#     'votes_with_party_pct': 92.18,
#     'contact_form': None,
#     'chamber': 'House',
#     'missed_votes_pct': 1.36,
#     'title': 'Representative',
#     'short_title': 'Rep.',
#     'total_votes': 955,
#     'missed_votes': 13,
#     'fec_candidate_id': 'H8WI01156',
#     'end_date': '2021-01-03',
#     'congress': '116',
#     'bills_sponsored': 12,
#     'cook_pvi': 'R+5',
#     'ocd_id': 'ocd-division/country:us/state:wi/cd:1',
#     'subcommittees': [{'code': 'HSBA04',
#       'begin_date': '',
#       'end_date': '2021-01-03',
#       'rank_in_party': 9,
#       'title': 'Member',
#       'side': 'minority',
#       'api_uri': 'https://api.propublica.org/congress/v1/116/house/committees/HSBA/subcommittees/HSBA04.json',
#       'parent_committee_id': 'HSBA',
#       'name': 'Housing, Community Development, and Insurance'},
#      {'rank_in_party': 7,
#       'name': 'Oversight and Investigations',
#       'begin_date': '',
#       'parent_committee_id': 'HSBA',
#       'title': 'Member',
#       'api_uri': 'https://api.propublica.org/congress/v1/116/house/committees/HSBA/subcommittees/HSBA09.json',
#       'side': 'minority',
#       'end_date': '2021-01-03',
#       'code': 'HSBA09'},
#      {'begin_date': '',
#       'side': 'minority',
#       'title': 'Member',
#       'api_uri': 'https://api.propublica.org/congress/v1/116/house/committees/HSBA/subcommittees/HSBA13.json',
#       'name': 'Diversity and Inclusion',
#       'rank_in_party': 8,
#       'code': 'HSBA13',
#       'end_date': '2021-01-03',
#       'parent_committee_id': 'HSBA'}],
#     'state': 'WI'}],
#   '_id': 'S001213',
#   'bio': {'current_party': 'R',
#    'last_name': 'Steil',
#    'dob': DatetimeWithNanoseconds(1981, 3, 30, 0, 0, tzinfo=<UTC>),
#    'gender': 'M',
#    'middle_name': None,
#    'first_name': 'Bryan'},
#   'other_ids': {'votesmart_id': '181289',
#    'google_id': '/g/11fhnfybnd',
#    'crp_id': 'N00043379',
#    'cspan_id': None,
#    'fec_id': 'H8WI01156',
#    'govtrack_id': '412836'}}]

# %% [markdown]
# ## Get Number of Current Congress

# %%
# Year of 1st Congress
begin = 1789

# Determine year to use
now = datetime.now().date()
if now.day >= 20:
    year = now.year
else:
    year = now.year - 1
    
# Determine current congress
current_cong_num = int(1 + (year - begin)/2)

# %%
print('Current Congress:', current_cong_num)

# %%
# House members of current congress
current_members = get_house_ids(current_cong_num)
members = [ get_member_data(mem) for mem in current_members ]

# %%
member = members[0]
sample_dict(member)

# %%
def get_roll_call_vote(congress, session_number, roll_call_num):
    query = f'{congress}/house/sessions/{session_number}/votes/{roll_call_num}.json'
    call_string = API_ROOT + query
    r = requests.get(call_string, headers=header)
    result = r.json()['results']['votes']
    
    return result
